# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\den19\OneDrive\Рабочий стол\Обучение\Домашнее задание\Аналитический проект на Python\ds_salaries.csv")

# %%
# 2. Изучение признаков и описательный анализ
print("Первые 5 строк датасета:")
print(df.head())

print("\nИнформация о датасете:")
print(df.info())

print("\nОписательная статистика числовых признаков:")
print(df.describe())

print("\nУникальные значения категориальных признаков:")
for col in df.select_dtypes(include='object').columns:
    print(f"\nУникальные значения для колонки '{col}':")
    print(df[col].unique())

# Гистограммы числовых признаков
df.hist(figsize=(15,10))
plt.tight_layout()
plt.show()

# Boxplots для выявления выбросов (особенно для salary_in_usd)
plt.figure(figsize=(12, 6))
sns.boxplot(x=df['salary_in_usd'])
plt.title('Boxplot для Salary in USD')
plt.show()
# Out:
# Первые 5 строк датасета:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# ...

# %%
# 3. Обработка пропусков и ошибок (если есть)
# Проверка на пропуски
print("\nКоличество пропущенных значений в каждой колонке:")
print(df.isnull().sum())
# Out:
# Количество пропущенных значений в каждой колонке:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
# Проверка на странные значения, например, в колонке experience_level
print("\nЗначения колонки experience_level:")
print(df['experience_level'].value_counts())
# Out:
# Значения колонки experience_level:
# experience_level
# SE    2516
# MI     805
# EN     320
# EX     114
# Name: count, dtype: int64

# %%
# 4. Удаление дубликатов
print("\nКоличество дубликатов в строках до удаления:")
print(df.duplicated().sum())

df.drop_duplicates(inplace=True)

print("\nКоличество дубликатов в строках после удаления:")
print(df.duplicated().sum())
# Out:
# Количество дубликатов в строках до удаления:
# 1171
#
# Количество дубликатов в строках после удаления:
# 0

# %%
# 5. Аналитика

# --- Высокооплачиваемые должности и выбросы ---
print("\n--- Высокооплачиваемые должности и выбросы ---")
# Out:
# --- Высокооплачиваемые должности и выбросы ---
